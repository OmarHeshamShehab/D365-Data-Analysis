# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file
file_path = 'PO_data.csv'  # Update this with your file path
df = pd.read_csv(file_path)

# Check for missing values
missing_data = df.isnull().sum().sort_values(ascending=False)
missing_percentage = (missing_data / len(df)) * 100

# Plot missing values (Top 20 columns)
plt.figure(figsize=(10,6))
sns.barplot(x=missing_percentage[:20], y=missing_percentage[:20].index)
plt.title('Top 90 Columns with Highest Missing Values (%)')
plt.xlabel('Percentage')
plt.ylabel('Columns')
plt.show()

# Filter only numerical columns for correlation matrix
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Correlation matrix for numerical fields
plt.figure(figsize=(12,10))
sns.heatmap(numeric_df.corr(), annot=False, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
missing_values = df.isnull().sum()

# %%
missing_percentage = (missing_values / len(df)) * 100

# %%
print("Missing Values in Each Column:\n", missing_values)
print("\nPercentage of Missing Data:\n", missing_percentage)
# Out:
# Missing Values in Each Column:
#  dataAreaId                            0
# PurchaseOrderNumber                   0
# FiscalDocumentOperationTypeId      2170
# ExpectedStoreAvailableSalesDate       0
# VendorInvoiceDeclarationId         2170
#                                    ...
# TransportationRoutePlanId          2170
# ZakatContractNumber                2170
# FormattedDeliveryAddress            109
# TotalDiscountVendorGroupCode       2141
# TradeEndCustomerAccount            2170
# Length: 118, dtype: int64
#
# Percentage of Missing Data:
#  dataAreaId                           0.000000
# PurchaseOrderNumber                  0.000000
# FiscalDocumentOperationTypeId      100.000000
# ExpectedStoreAvailableSalesDate      0.000000
# VendorInvoiceDeclarationId         100.000000
#                                       ...
# TransportationRoutePlanId          100.000000
# ZakatContractNumber                100.000000
# FormattedDeliveryAddress             5.023041
# TotalDiscountVendorGroupCode        98.663594
# TradeEndCustomerAccount            100.000000
# Length: 118, dtype: float64

# %%
data_cleaned = df.dropna()

# %%
print("\nMissing values in each column after removal:")
print(data_cleaned.isnull().sum())
# Out:
# Missing values in each column after removal:
# dataAreaId                         0
# PurchaseOrderNumber                0
# FiscalDocumentOperationTypeId      0
# ExpectedStoreAvailableSalesDate    0
# VendorInvoiceDeclarationId         0
#                                   ..
# TransportationRoutePlanId          0
# ZakatContractNumber                0
# FormattedDeliveryAddress           0
# TotalDiscountVendorGroupCode       0
# TradeEndCustomerAccount            0
# Length: 118, dtype: int64

# %%
df.head(5)
# Out:
#   dataAreaId PurchaseOrderNumber  FiscalDocumentOperationTypeId  \
# 0       ussi            00000002                            NaN
# 1       ussi            00000003                            NaN
# 2       ussi            00000004                            NaN
# 3       ussi            00000005                            NaN
# 4       ussi            00000006                            NaN
#
#   ExpectedStoreAvailableSalesDate  VendorInvoiceDeclarationId  DeliveryModeId  \
# 0            1900-01-01T12:00:00Z                         NaN             NaN
# 1            1900-01-01T12:00:00Z                         NaN             NaN
# 2            1900-01-01T12:00:00Z                         NaN             NaN
# 3            1900-01-01T12:00:00Z                         NaN             NaN
# 4            1900-01-01T12:00:00Z                         NaN             NaN
#
#    InvoiceAddressStreet OrderVendorAccountNumber Email  TransportationModeId  \
# 0                   NaN             US_SI_000014   NaN                   NaN
# 1                   NaN             US_SI_000020   NaN                   NaN
# 2                   NaN             US_SI_000015   NaN                   NaN
# 3                   NaN             US_SI_000014   NaN                   NaN
# 4                   NaN             US_SI_000021   NaN                   NaN
#
#    ... OrdererPersonnelNumber  VendorPaymentMethodName InvoiceAddressState  \
# 0  ...                  355.0                      NaN                 NaN
# 1  ...                  355.0                      NaN                 NaN
# 2  ...                  355.0                      NaN                 NaN
# 3  ...                  355.0                      NaN                 NaN
# 4  ...                  355.0                      NaN                 NaN
#
#    DefaultReceivingSiteId  LineDiscountVendorGroupCode  \
# 0                     NaN                          NaN
# 1                     NaN                          NaN
# 2                     NaN                          NaN
# 3                     NaN                          NaN
# 4                     NaN                          NaN
#
#    TransportationRoutePlanId ZakatContractNumber  \
# 0                        NaN                 NaN
# 1                        NaN                 NaN
# 2                        NaN                 NaN
# 3                        NaN                 NaN
# 4                        NaN                 NaN
#
#                             FormattedDeliveryAddress  \
# 0  454 1st Street\nSuite 99\nRedmond, WA 98052 \nUSA
# 1  454 1st Street\nSuite 99\nRedmond, WA 98052 \nUSA
# 2  454 1st Street\nSuite 99\nRedmond, WA 98052 \nUSA
# 3  454 1st Street\nSuite 99\nRedmond, WA 98052 \nUSA
# 4  454 1st Street\nSuite 99\nRedmond, WA 98052 \nUSA
#
#    TotalDiscountVendorGroupCode TradeEndCustomerAccount
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
# [5 rows x 118 columns]
